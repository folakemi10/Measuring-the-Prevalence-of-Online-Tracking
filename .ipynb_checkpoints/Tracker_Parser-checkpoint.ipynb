# %%
import os
import json
import matplotlib.pyplot as plt
import tldextract
from collections import Counter


vanilla_dir = "C:/Users/18707/Desktop/tracker-radar-collector/vanilla_data"
adblock_dir = "C:/Users/18707/Desktop/tracker-radar-collector/adblock_data"
standard_file = "C:/Users/18707/Desktop/tracker-radar-collector/standard-headers.txt"

def count_requests(data_dir):
    counts = {}
    for filename in os.listdir(data_dir):
        if filename.endswith(".json"):
            with open(os.path.join(data_dir, filename), "r") as file:
                data = json.load(file)
                initial_url = data.get("initialUrl")
                
# doing this check because i got an error message otherwise 
                if initial_url is not None:
                    parsed_url = tldextract.extract(initial_url)
                    domain = parsed_url.domain

                    requests = data.get("data", {}).get("requests", [])
                    requests_count = 0
                    for request in requests:
                        request_url = request.get("url")
                        parsed_request_url = tldextract.extract(request_url)
                        request_domain = parsed_request_url.domain
                        if domain != request_domain:
                            requests_count += 1

                counts[domain] = requests_count
    return counts


def count_cookies(data_dir):
    counts = {}
    for filename in os.listdir(data_dir):
        if filename.endswith(".json"):
            with open(os.path.join(data_dir, filename), "r") as file:
                data = json.load(file)
                initial_url = data.get("initialUrl")
                
# doing this check because i got an error message otherwise 
                if initial_url is not None:
                    parsed_url = tldextract.extract(initial_url)
                    domain = parsed_url.domain
                    cookies = data.get("data", {}).get("cookies", [])
                    
                    cookie_domains = set()
                    for cookie in cookies:
                        if "domain" in cookie:
                            cookie_domain = cookie["domain"]
                            parsed_cookie_domain = tldextract.extract(cookie_domain)
                            if domain != (parsed_cookie_domain.domain):
                                cookie_domains.add(cookie_domain)

                counts[filename] = len(cookie_domains)
    return counts
 
def count_api(data_dir):
    api_calls = {}
    for filename in os.listdir(data_dir):
        if filename.endswith(".json"):
            with open(os.path.join(data_dir, filename), "r") as file:
                data = json.load(file)
                callStats = data.get("data", {}).get("apis", {}).get("callStats", {})
                initial_url = data.get("initialUrl")
 # doing this check because i got an error message otherwise 
                if initial_url is not None:
                    parsed_url = tldextract.extract(initial_url)
                    domain = parsed_url.domain
                    num_calls = len(callStats)
                    api_calls[domain] = num_calls
    return api_calls


def count_header(data_dir):
    with open(standard_file, "r") as file:
        standard_headers = file.read().splitlines()

    custom_headers = {}
    
    for filename in os.listdir(data_dir):
        if filename.endswith(".json"):
            with open(os.path.join(data_dir, filename), "r") as file:
                data = json.load(file)
                initial_url = data.get("initialUrl")
                
# doing this check because i got an error message otherwise                 
                if initial_url is not None:
                    parsed_url = tldextract.extract(initial_url)
                    domain = parsed_url.domain
                    requests = data.get("data", {}).get("requests", [])

                    custom_headers_count = 0
                    for request in requests:
                        response_headers = request.get("responseHeaders", {})
                        
                        for header_name in response_headers:
                            if header_name not in standard_headers:
                                custom_headers_count += 1

                    custom_headers[domain] = custom_headers_count

    return custom_headers

def get_top_10(data):
    domain_counts = Counter(data)
    top_10_domains = domain_counts.most_common(10)
    return top_10_domains

def plot_requests_distribution(data, types, mode):
    plt.figure(figsize=(12, 6))
    plt.bar(range(len(data)), list(data.values()), align='center', color='skyblue')
    plt.xticks(range(len(data)), list(data.keys()), rotation=90)
    plt.title(f"Distribution of Third-Party {types} in {mode} Mode")
    plt.xlabel("Website Domain")
    plt.ylabel(f"Number of Third-Party {types}")
    plt.tight_layout()
    plt.show()

# %%
    
vanilla_requests = count_requests(vanilla_dir)
plot_requests_distribution(vanilla_requests, "Requests", "Vanilla")
    
add_requests = count_requests(adblock_dir)
plot_requests_distribution(add_requests,"Requests", "AdBlock")


vanilla_cookies = count_cookies(vanilla_dir)
plot_requests_distribution(vanilla_cookies, "Cookies", "Vanilla")

add_cookies = count_cookies(adblock_dir)
plot_requests_distribution(add_cookies, "Cookies", "AdBlock")


vanilla_apis= count_api(vanilla_dir)
plot_requests_distribution(vanilla_apis, "API Calls", "Vanilla")

add_apis = count_api(adblock_dir)
plot_requests_distribution(add_apis, "API Calls", "AdBlock")


vanilla_header= count_header(vanilla_dir)
plot_requests_distribution(vanilla_header, "Custom Headers", "Vanilla")

add_header = count_header(adblock_dir)
plot_requests_distribution(add_header, "Custom Headers", "AdBlock")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 22
#      18 add_apis = count_api(adblock_dir)
#      19 plot_requests_distribution(add_apis, "API Calls", "AdBlock")
# ---> 22 vanilla_header= count_header(vanilla_dir)
#      23 plot_requests_distribution(vanilla_header, "Custom Headers", "Vanilla")
#      25 add_header = count_header(adblock_dir)
#
# Cell In[19], line 81, in count_header(data_dir)
#      80 def count_header(data_dir):
# ---> 81     with open(standard_file, "r") as file:
#      82         standard_headers = file.read().splitlines()
#      84     custom_headers = {}
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/18707/Desktop/tracker-radar-collector/standard_headers.txt'

# %%
top_request = get_top_10(vanilla_requests)
print("Top 10 Third-Party Domains for Request URLs")
for domain, count in top_request:
    print(f"{domain}: {count}")
    
top_cookie = get_top_10(vanilla_cookies)
print("\nTop 10 Third-Party Domains for Cookies")
for domain, count in top_cookie:
    print(f"{domain}: {count}")

top_api = get_top_10(vanilla_apis)
print("\nTop 10 Third-Party Domains for JavaScript Api Calls")
for domain, count in top_api:
    print(f"{domain}: {count}")
    
top_header = get_top_10(vanilla_header)
print("\nTop 10 Third-Party Domains for Custom Headers")
for domain, count in top_header:
    print(f"{domain}: {count}")
# Out:
# Top 10 Third-Party Domains for Request URLs
# douyin: 460
# go: 286
# espn: 257
# scmp: 254
# qq: 235
# msn: 232
# techradar: 232
# dailymail: 229
# foxnews: 227
# nypost: 210
#
# Top 10 Third-Party Domains for Cookies
# msn.com_ef86.json: 5
# theverge.com_d5c0.json: 4
# cbslocal.com_d04b.json: 3
# douyin.com_de5a.json: 3
# fortune.com_2c17.json: 3
# rollingstone.com_4a3d.json: 3
# slate.com_66bb.json: 3
# sputniknews.com_173d.json: 3
# thenation.com_1960.json: 3
# cnbc.com_b430.json: 2
#
# Top 10 Third-Party Domains for JavaScript Api Calls
# douyin: 54
# foxnews: 38
# mirror: 37
# variety: 34
# theverge: 30
# nbcnews: 28
# nypost: 25
# scmp: 23
# msn: 20
# go: 18
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 16
#      13 for domain, count in top_api:
#      14     print(f"{domain}: {count}")
# ---> 16 top_header = get_top_10(vanilla_header)
#      17 print("\nTop 10 Third-Party Domains for Custom Headers")
#      18 for domain, count in top_header:
#
# NameError: name 'vanilla_header' is not defined

# %%
vanilla_third_party_requests = count_third_party_requests(vanilla_data_dir)
top_10_request_domains = get_top_10_domains(vanilla_third_party_requests)

print("Top 10 Third-Party Domains for Request URLs in Vanilla Mode:")
for domain, count in top_10_request_domains:
    print(f"{domain}: {count}")
    
    
    
vanilla_third_party_cookies = count_third_party_cookies(vanilla_data_dir)
top_10_cookie_domains = get_top_10_domains(vanilla_third_party_cookies)
print("\nTop 10 Third-Party Domains for Cookies in Vanilla Mode:")
for domain, count in top_10_cookie_domains:
    print(f"{domain}: {count}")
# Out:
# Top 10 Third-Party Domains for Request URLs in Vanilla Mode:
# dailymail.co.uk_1150.json: 471
# msn.com_ef86.json: 445
# asahi.com_f90e.json: 395
# douyin.com_de5a.json: 366
# techradar.com_ac75.json: 336
# cnn.com_f46a.json: 331
# kotaku.com_b940.json: 325
# abcnews.go.com_b589.json: 320
# tmz.com_aa46.json: 300
# thenation.com_1960.json: 298
#
# Top 10 Third-Party Domains for Cookies in Vanilla Mode:
# huffpost.com_1baa.json: 49
# techradar.com_ac75.json: 46
# businessinsider.com_e194.json: 44
# cnn.com_f46a.json: 43
# fortune.com_2c17.json: 40
# theguardian.com_4785.json: 40
# foreignpolicy.com_d2d3.json: 38
# bonappetit.com_11be.json: 37
# aljazeera.com_5984.json: 36
# buzzfeed.com_ec65.json: 33

# %%
vanilla_third_party_cookies = count_third_party_cookies(vanilla_data_dir)
plot_cookies_distribution(vanilla_third_party_requests, "Vanilla")

add_block_third_party_requests = count_third_party_cookies(adblock_data_dir)
plot_cookies_distribution(add_block_third_party_requests, "add_block")

# %%
def count_api_calls(data_dir):
    api_calls = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".json"):
            with open(os.path.join(data_dir, filename), "r") as file:
                data = json.load(file)
                apis = data.get("data", {}).get("apis", {}).get("callStats", {})
                for api_url, calls in apis.items():
                    total_calls = sum(calls.values())
                    api_calls.append((api_url, total_calls))
    return api_calls

def get_top_10_domains(data):
    domain_counts = Counter()
    for api_url, calls in data:
        domain = api_url.split("//")[-1].split("/")[0]
        domain_counts[domain] += calls
    top_10_domains = domain_counts.most_common(10)
    return top_10_domains

vanilla_api_calls = count_api_calls(vanilla_data_dir)
top_10_api_domains = get_top_10_domains(vanilla_api_calls)

print("Top 10 Third-Party Domains Making JavaScript API Calls in Vanilla Mode:")
for domain, calls in top_10_api_domains:
    print(f"{domain}: {calls}")

# Step 5: Plot the Distribution of JavaScript API Calls
api_calls_distribution = [calls for _, calls in vanilla_api_calls]
plt.hist(api_calls_distribution, bins=20, color='blue', alpha=0.5)
plt.xlabel('Number of JavaScript API Calls')
plt.ylabel('Frequency')
plt.title('Distribution of JavaScript API Calls by Third-Party Domains (Vanilla Mode)')
plt.grid(True)
plt.show()
# Out:
# Top 10 Third-Party Domains Making JavaScript API Calls in Vanilla Mode:
# a.teads.tv: 43298
# www.googletagmanager.com: 24272
# www.bbc.com: 23248
# z.moatads.com: 16481
# feliz-web.data.tm-awx.com: 15578
# c.amazon-adsystem.com: 13461
# securepubads.g.doubleclick.net: 12760
# assets-v2.i-scmp.com: 9723
# micro.rubiconproject.com: 9260
# cdn.privacy.paramount.com: 8445
